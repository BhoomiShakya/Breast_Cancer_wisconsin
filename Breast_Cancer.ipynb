# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data = data.drop(['id', 'Unnamed: 32'], axis = 1)
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['diagnosis'] = encoder.fit_transform(data['diagnosis'])
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
X = data.iloc[:, 1:] # Variables
Y = data.iloc[:, 0] # Result

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size = 0.2, random_state = 0)
# test_size : amount of data used for testing
# random_state : Controls the shuffling applied tot he data before applying the split
test_X.shape
# Out:
# (114, 30)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
Classifier = Sequential()
Classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
Classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
Classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
Classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history = Classifier.fit(train_X, train_Y, epochs = 50, batch_size = 10, validation_data = (test_X, test_Y))
# Out:
# Epoch 1/50
# 46/46 [==============================] - 2s 7ms/step - loss: 0.6910 - accuracy: 0.6000 - val_loss: 0.6894 - val_accuracy: 0.5877
# Epoch 2/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6793 - accuracy: 0.6527 - val_loss: 0.6666 - val_accuracy: 0.6930
# Epoch 3/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6292 - accuracy: 0.8352 - val_loss: 0.5941 - val_accuracy: 0.7719
# Epoch 4/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5134 - accuracy: 0.8769 - val_loss: 0.4402 - val_accuracy: 0.9035
# Epoch 5/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.3772 - accuracy: 0.9143 - val_loss: 0.3347 - val_accuracy: 0.9035
# Epoch 6/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.2861 - accuracy: 0.9099 - val_loss: 0.2570 - val_accuracy: 0.9123
# Epoch 7/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.2285 - accuracy: 0.9341 - val_loss: 0.2229 - val_accuracy: 0.8947
# Epoch 8/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.2002 - accuracy: 0.9297 - val_loss: 0.1977 - val_accuracy: 0.9123
# Epoch 9/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.1766 - accuracy: 0.9473 - val_loss: 0.1904 - val_accuracy: 0.9298
# Epoch 10/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.1625 - accuracy: 0.9429 - val_loss: 0.1736 - val_accuracy: 0.9123
# Epoch 11/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9516 - val_loss: 0.1664 - val_accuracy: 0.9298
# Epoch 12/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.1392 - accuracy: 0.9495 - val_loss: 0.1585 - val_accuracy: 0.9211
# Epoch 13/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.1329 - accuracy: 0.9582 - val_loss: 0.1543 - val_accuracy: 0.9298
# Epoch 14/50
# 46/46 [==============================] - 0s 6ms/step - loss: 0.1280 - accuracy: 0.9516 - val_loss: 0.1483 - val_accuracy: 0.9211
# Epoch 15/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.1169 - accuracy: 0.9604 - val_loss: 0.1454 - val_accuracy: 0.9123
# Epoch 16/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.1129 - accuracy: 0.9670 - val_loss: 0.1381 - val_accuracy: 0.9474
# Epoch 17/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.1059 - accuracy: 0.9692 - val_loss: 0.1463 - val_accuracy: 0.9211
# Epoch 18/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.1026 - accuracy: 0.9714 - val_loss: 0.1314 - val_accuracy: 0.9298
# Epoch 19/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9758 - val_loss: 0.1302 - val_accuracy: 0.9298
# Epoch 20/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.9736 - val_loss: 0.1283 - val_accuracy: 0.9298
# Epoch 21/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9736 - val_loss: 0.1222 - val_accuracy: 0.9649
# Epoch 22/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9714 - val_loss: 0.1229 - val_accuracy: 0.9649
# Epoch 23/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9670 - val_loss: 0.1228 - val_accuracy: 0.9561
# Epoch 24/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.9736 - val_loss: 0.1182 - val_accuracy: 0.9737
# Epoch 25/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 0.9736 - val_loss: 0.1183 - val_accuracy: 0.9649
# Epoch 26/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0794 - accuracy: 0.9736 - val_loss: 0.1160 - val_accuracy: 0.9737
# Epoch 27/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9736 - val_loss: 0.1148 - val_accuracy: 0.9737
# Epoch 28/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0767 - accuracy: 0.9780 - val_loss: 0.1144 - val_accuracy: 0.9737
# Epoch 29/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0745 - accuracy: 0.9824 - val_loss: 0.1140 - val_accuracy: 0.9649
# Epoch 30/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9802 - val_loss: 0.1169 - val_accuracy: 0.9561
# Epoch 31/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0703 - accuracy: 0.9846 - val_loss: 0.1126 - val_accuracy: 0.9737
# Epoch 32/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0703 - accuracy: 0.9780 - val_loss: 0.1145 - val_accuracy: 0.9649
# Epoch 33/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0676 - accuracy: 0.9846 - val_loss: 0.1142 - val_accuracy: 0.9649
# Epoch 34/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9846 - val_loss: 0.1275 - val_accuracy: 0.9474
# Epoch 35/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9824 - val_loss: 0.1132 - val_accuracy: 0.9737
# Epoch 36/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9780 - val_loss: 0.1172 - val_accuracy: 0.9561
# Epoch 37/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9824 - val_loss: 0.1150 - val_accuracy: 0.9649
# Epoch 38/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9802 - val_loss: 0.1144 - val_accuracy: 0.9649
# Epoch 39/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9802 - val_loss: 0.1236 - val_accuracy: 0.9561
# Epoch 40/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9802 - val_loss: 0.1148 - val_accuracy: 0.9649
# Epoch 41/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0619 - accuracy: 0.9890 - val_loss: 0.1145 - val_accuracy: 0.9737
# Epoch 42/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9846 - val_loss: 0.1193 - val_accuracy: 0.9561
# Epoch 43/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9824 - val_loss: 0.1175 - val_accuracy: 0.9649
# Epoch 44/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9824 - val_loss: 0.1163 - val_accuracy: 0.9649
# Epoch 45/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9824 - val_loss: 0.1162 - val_accuracy: 0.9737
# Epoch 46/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 0.9824 - val_loss: 0.1170 - val_accuracy: 0.9737
# Epoch 47/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9802 - val_loss: 0.1179 - val_accuracy: 0.9649
# Epoch 48/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.9824 - val_loss: 0.1189 - val_accuracy: 0.9649
# Epoch 49/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9868 - val_loss: 0.1184 - val_accuracy: 0.9649
# Epoch 50/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 0.9846 - val_loss: 0.1201 - val_accuracy: 0.9649

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
fig = plt.figure(figsize = (10, 10), edgecolor = 'Black')
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
ax1.plot(epochs, accuracy, label = 'Training Accuracy')
ax1.plot(epochs, val_accuracy, label = 'Validation Accuracy')
ax1.set_title("Training and Validation accuracy", fontsize = 20)
ax1.set_ylabel("Accuracy", fontsize = 15)
ax1.legend()
ax2.plot(epochs, loss, label = 'Training Loss')
ax2.plot(epochs, val_loss, label = 'Validation Loss')
ax2.set_title("Training and Validation Loss", fontsize = 20)
ax2.set_ylabel("Loss", fontsize = 15)
ax2.legend()
plt.show()

# %%
Y_pred = Classifier.predict(test_X)
# Probability showing the individual having breast cancer (Malignant)
# Probability over 50% would indicate the presence of breast cancer
Y_pred = (Y_pred > 0.5) # Converting the probabilities into 'True' and 'False
# Out:
# 4/4 [==============================] - 0s 14ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_Y, Y_pred)
cm
# Out:
# array([[66,  1],
#        [ 3, 44]])

# %%
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %%
print("Accuracy Score:", round((cm[0, 0]+cm[1, 1])/(cm[0, 0]+cm[0, 1]+cm[1, 0]+cm[1, 1])*100)) #, 2
# Out:
# Accuracy Score: 96
